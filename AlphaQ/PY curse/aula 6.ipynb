# %% [markdown]
# List

# %%
numeros = [1,2,3,4,5]

# To add elements
numeros.append(8)

# To remove
numeros.remove(2)

numeros
numeros = [1,2,3,4,5]

# %% [markdown]
# List comprehesion

# %%
quadrados = [n**2 for n in range(1,6)]
print(quadrados)
# Out:
# [1, 4, 9, 16, 25]

# %%
pares = [n**2 for n in range(10) if n % 2 == 0 and n != 0]
print(pares)
# Out:
# [4, 16, 36, 64]

# %% [markdown]
# Tuple

# %%
cores = ("vermelho", "verde", "azul")
cores[0]
# Out:
# 'vermelho'

# %%
r, g, b = cores
r
# Out:
# 'vermelho'
