# %%
def saudacao (nome, saudacao= "Olá"):
    return print(f'{nome},{saudacao}')

# %%
saudacao("a", "oi")
# Out:
# a,oi

# %%
# To can put in how many args that i want

def somar_tudo (*args):
    return sum(args)

# %%
somar_tudo(1,2,3,4, 5,6,4,7,8)
# Out:
# 40

# %% [markdown]
# To modify a global variable into other element

# %%
x = 10
print(x)

def alterar_global ():
    global x
    x = 20

alterar_global()
print(x)
# Out:
# 10
# 20
