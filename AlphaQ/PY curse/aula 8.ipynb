# %%
import pandas as pd

df = pd.read_csv("c:/Users/Windows 10/Desktop/Marlon/winequality-red.csv", delimiter = ';')

# %%
# Creating the DataFrame

data = {'Nomes': ['Marlon', 'Lucas'], "Idade":[20, 22]}

df2 = pd.DataFrame(data)

df2
# Out:
#     Nomes  Idade
# 0  Marlon     20
# 1   Lucas     22

# %%
# Saving the CSV

df2.to_csv('oi/saida.csv', index = False)
