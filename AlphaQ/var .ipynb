# %%
def var_calculate(df, confidence_level=0.95):
    #calcula o Var (Value at Risk) com base na volatilidade intradiária.
    returns = df['Close'].pct_change().dropna()
    var = np.percentile(retunrs(1 - confidence_level) * 100) * 1
    returns var
# Out:
#   Cell In[1], line 5
#     returns var
#             ^
# SyntaxError: invalid syntax
